# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x=np.arange(-5,5,0.1)
y=x**2

plt.ylabel('Y')
plt.xlabel('X')
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
z = x**3

plt.plot(x,y)
plt.plot(x,z)
plt.show()
