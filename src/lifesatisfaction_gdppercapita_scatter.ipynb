# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('country_stat.csv')
data
# Out:
#             Country  GDP per capita  Life satisfaction
# 0            Mexico        9009.280                6.6
# 1            Russia        9054.914                6.0
# 2            Turkey        9437.372                5.5
# 3           Hungary       12239.894                5.3
# 4             Chile       13340.905                6.7
# 5   Slovak Republic       15991.736                6.1
# 6    Czech Republic       17256.918                6.6
# 7           Estonia       17288.083                5.6
# 8            Greece       18064.288                5.2
# 9          Portugal       19121.592                5.2
# 10         Slovenia       20732.482                5.8
# 11            Spain       25864.721                6.4
# 12            Korea       27195.197                5.9
# 13            Italy       29866.581                5.9
# 14            Japan       32485.545                5.9
# 15           Israel       35343.336                7.2
# 16      New Zealand       37044.891                7.3
# 17           France       37675.006                6.4
# 18          Belgium       40106.632                6.9
# 19          Germany       40996.511                7.0
# 20          Finland       41973.988                7.5
# 21           Canada       43331.961                7.3
# 22      Netherlands       43603.115                7.4
# 23          Austria       43724.031                7.0
# 24   United Kingdom       43770.688                6.7
# 25           Sweden       49866.266                7.3
# 26          Iceland       50854.583                7.5
# 27        Australia       50961.865                7.3
# 28          Ireland       51350.744                7.0

# %%
gdp_per_capita = data['GDP per capita']
life_satisfaction = data['Life satisfaction']

# %%
plt.scatter(gdp_per_capita, life_satisfaction)
plt.show()
